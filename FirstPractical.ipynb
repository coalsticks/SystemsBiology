# %%
# !ls
# Out:
# FirstPractical.ipynb

# %%
# !find . | head
# Out:
# .
# ./FirstPractical.ipynb
# ./.ipynb_checkpoints
# ./.ipynb_checkpoints/FirstPractical-checkpoint.ipynb

# %%
# %cd datasets/
# Out:
# /home/larissa/Systems Biology/datasets

# %%
# !ls

# %%
# %cd ..
# Out:
# /home/larissa/Systems Biology

# %%
# !ls
# Out:
# datasets  FirstPractical.ipynb

# %%
# %time 1*2
# Out:
# CPU times: user 17 μs, sys: 5 μs, total: 22 μs
# Wall time: 64.1 μs
# 2

# %%
# %timeit 1*2
# Out:
# 5.43 ns ± 0.211 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
import math

# %%
# %timeit math.exp(2)
# Out:
# 46.4 ns ± 1.99 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
